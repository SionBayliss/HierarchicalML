# %% [markdown]
# # classify new data using pre-run model

# %%
# dependencies 
import networkx as nx
import numpy as np
import pandas as pd

import copy 
import sys
import gzip
import pickle
import time

from sklearn.model_selection import train_test_split, RandomizedSearchCV, StratifiedKFold, cross_validate
from sklearn.metrics import accuracy_score, balanced_accuracy_score, confusion_matrix, classification_report

# import hierarchical classification package
sys.path.append( '../../HC_package/' )
from HierarchicalClassification import *

# %%
# set variables 
data_file = "patterns.tab"
class_file = "sample.location" 
output_file = "output_"
include_file = "sample_list.txt"

n_jobs = -1
seed = 34

# %%
# classificaton mode and thresholds
mode = 'max' # maximum class proedicted probability
threshold = 'adaptive' # minimum threshold value is 1/number of classes in model - this can also be a set value e.g. 0.5

# %% [markdown]
# ## load dataset and expected classes

# %%
# features
raw_features  = pd.read_csv(data_file, sep = "\t", index_col = "pattern_id")

# %%
# labels 
raw_labels = pd.read_csv(class_file, sep = "\t", header = None, index_col = 0)

# samples to include - just an index
include = pd.read_csv(include_file, sep = "\t", header = None, index_col = 0)

# %%
# find intersection between sample list and those included in features
inc = include.index.values
in_feat = raw_features.columns

intersect = []
for i in include.index.values:
    if i in in_feat:
        intersect.append(i)
        
print("original samples to include:", len(inc))
print("samples present in data:", len(intersect))
# Out:
# original samples to include: 35
# samples present in data: 35

# %%
# filter feature/labels on include
new_features = raw_features.loc[:, intersect]

# %%
# order labels on colnames of features
lab_ind = pd.DataFrame(index=new_features.columns)
new_labels = lab_ind.join(raw_labels)[1]

print(new_features.shape)
print(new_labels.shape)
# Out:
# (94860, 35)
# (35,)

# %%
# load trained model
with gzip.open("../../model_outputs/models.pkl.gz", 'rb') as f:
    models = pickle.load(f)

# %%
# load graph
with open("../../data/graph.pkl", 'rb') as f:
    graph = pickle.load(f)

# %%
# load model feature names
train_feat = np.loadtxt("../../data/feature_list.txt", dtype = int)

# %%
# filter input features on model features (train_features) and transpose
input_converted = copy.copy(new_features.loc[train_feat].T)
print(input_converted.shape)
input_converted
# Out:
# (35, 89481)
# pattern_id  1       2       3       4       5       6       7       12      \
# ERR2278721       1       1       1       1       1       1       1       0
# ERR2278723       1       1       1       1       1       1       1       0
# ERR2278728       1       1       1       1       1       1       1       0
# ERR2278729       1       1       1       1       1       1       1       0
# ERR2278733       1       1       1       1       1       1       1       0
# ERR2278739       1       1       1       1       1       1       1       0
# ERR2278742       1       1       1       1       1       1       1       0
# ERR2278743       1       1       1       1       1       1       1       0
# ERR2278749       1       1       1       1       1       1       1       0
# ERR2278713       1       1       1       1       1       1       1       0
# ERR2278717       1       1       1       1       1       1       1       0
# ERR2278720       1       1       1       1       1       1       1       0
# ERR2278726       1       1       1       1       1       1       1       0
# ERR2278727       1       1       1       1       1       1       1       0
# ERR2278735       1       1       1       1       1       1       1       0
# ERR2278716       1       1       1       1       1       1       1       0
# ERR2278718       1       1       1       1       1       1       1       0
# ERR2278724       1       1       1       1       1       1       1       0
# ERR2278736       1       1       1       1       1       1       1       0
# ERR2278738       1       1       1       1       1       1       1       0
# ERR2278731       1       1       1       1       1       1       1       0
# ERR2278734       1       1       1       1       1       1       1       0
# ERR2278741       1       1       1       1       1       1       1       0
# ERR2278745       1       1       1       1       1       1       1       0
# ERR2278714       1       1       1       1       1       1       1       0
# ERR2278715       1       1       1       1       1       1       1       0
# ERR2278719       1       1       1       1       1       1       1       0
# ERR2278722       1       1       1       1       1       1       1       0
# ERR2278725       1       1       1       1       1       1       1       0
# ERR2278737       1       1       1       1       1       0       1       0
# ERR2278740       1       1       1       1       1       1       1       0
# ERR2278744       1       1       1       1       1       1       1       0
# ERR2278746       1       1       1       1       1       1       1       0
# ERR2278747       1       1       1       1       1       1       1       0
# ERR2278748       1       1       1       1       1       1       1       0
#
# pattern_id  13      14      ...  110468  110469  110470  110471  110472  \
# ERR2278721       1       1  ...       0       0       1       0       0
# ERR2278723       1       1  ...       0       0       1       0       0
# ERR2278728       1       1  ...       0       0       1       0       0
# ERR2278729       1       1  ...       0       0       1       0       0
# ERR2278733       1       1  ...       0       0       1       0       0
# ERR2278739       1       1  ...       0       0       1       0       0
# ERR2278742       1       1  ...       0       0       1       0       0
# ERR2278743       1       1  ...       0       0       1       0       0
# ERR2278749       1       1  ...       0       0       1       0       0
# ERR2278713       1       1  ...       0       0       1       0       0
# ERR2278717       1       1  ...       0       0       1       0       0
# ERR2278720       1       1  ...       0       0       1       0       0
# ERR2278726       1       1  ...       0       0       1       0       0
# ERR2278727       1       1  ...       0       0       1       0       0
# ERR2278735       1       1  ...       0       0       1       0       0
# ERR2278716       1       1  ...       0       0       1       0       0
# ERR2278718       1       1  ...       0       0       1       0       0
# ERR2278724       1       1  ...       0       0       1       0       0
# ERR2278736       1       1  ...       0       0       1       0       0
# ERR2278738       1       1  ...       0       0       1       0       0
# ERR2278731       1       1  ...       0       0       1       0       0
# ERR2278734       1       1  ...       0       0       1       0       0
# ERR2278741       1       1  ...       0       0       1       0       0
# ERR2278745       1       1  ...       0       0       1       0       0
# ERR2278714       1       1  ...       0       0       1       0       0
# ERR2278715       1       1  ...       0       0       1       0       0
# ERR2278719       1       1  ...       0       0       1       0       0
# ERR2278722       1       1  ...       0       0       1       0       0
# ERR2278725       1       1  ...       0       0       1       0       0
# ERR2278737       1       1  ...       0       0       1       0       0
# ERR2278740       1       1  ...       0       0       1       0       0
# ERR2278744       1       1  ...       0       0       1       0       0
# ERR2278746       0       1  ...       0       0       1       0       0
# ERR2278747       1       1  ...       0       0       1       0       0
# ERR2278748       1       1  ...       0       0       1       0       0
#
# pattern_id  110474  110476  110479  110480  110483
# ERR2278721       1       0       0       0       0
# ERR2278723       1       0       0       0       0
# ERR2278728       1       0       0       0       0
# ERR2278729       1       0       0       0       0
# ERR2278733       1       0       0       0       0
# ERR2278739       1       0       0       0       0
# ERR2278742       1       0       0       0       0
# ERR2278743       1       0       0       0       0
# ERR2278749       1       0       0       0       0
# ERR2278713       1       0       0       0       0
# ERR2278717       1       0       0       0       0
# ERR2278720       1       0       0       0       0
# ERR2278726       1       0       0       0       0
# ERR2278727       1       0       0       0       0
# ERR2278735       1       0       0       0       0
# ERR2278716       1       0       0       0       0
# ERR2278718       1       0       0       0       0
# ERR2278724       1       0       0       0       0
# ERR2278736       1       0       0       0       0
# ERR2278738       1       0       0       0       0
# ERR2278731       1       0       0       0       0
# ERR2278734       1       0       0       0       0
# ERR2278741       1       0       0       0       0
# ERR2278745       1       0       0       0       0
# ERR2278714       1       0       0       0       0
# ERR2278715       1       0       0       0       0
# ERR2278719       1       0       0       0       0
# ERR2278722       1       0       0       0       0
# ERR2278725       1       0       0       0       0
# ERR2278737       1       0       0       0       0
# ERR2278740       1       0       0       0       0
# ERR2278744       1       0       0       0       0
# ERR2278746       1       0       0       0       0
# ERR2278747       1       0       0       0       0
# ERR2278748       1       0       0       0       0
#
# [35 rows x 89481 columns]

# %% [markdown]
# ## classify samples

# %%
# classify samples
timeb4 = time.time()

# classify test sample
(classification_table_test, classifications_test) = classify_samples_in_hierarchy(graph, input_converted, 
                                                                           models,
                                                                           mode = mode, 
                                                                           threshold = threshold)


timeafter = time.time()
total_seconds = timeafter-timeb4
print("classification took ", total_seconds, " seconds")
# Out:
#  - WARNING: Samples have been assigned to multiple classes, try increasing threshold (>0.5) to prevent this behaviour. Classes:  ['ERR2278719']
# classification took  2.588233709335327  seconds

# %%
# generate per class statistics
(summary_test, summary_table_test) = summary_statistics_per_class(graph, new_labels, classifications_test,
                                                                         penalty=False, macro_inc_all = False)
#print( summary_test, summary_table_test) 
print(summary_test['macro'])
print(summary_test['micro'])
# Out:
# {'hR': 0.8444444444444446, 'hP': 0.8467032967032968, 'F1': 0.8455723620085919}
# {'hR': 0.7596899224806202, 'hP': 0.620253164556962, 'F1': 0.6829268292682927}

# %%
# convert class dist into table 

# create df
col_names = ["hP", "hR", "hF1", "n", "nP", "nT", "root_dist"]
class_table =  pd.DataFrame(
    columns = col_names,
    index = summary_test['per_class'])

# fill table
for i in summary_test['per_class']:
    for j in col_names:
        class_table.loc[i, j] = summary_test['per_class'][i][j]
    
# sort on class names and root_dist 
class_table.sort_index(inplace=True)
class_table.sort_values(by=['root_dist'], inplace=True)

# %%
# save per class hierachical summary values 
class_table.to_csv(( "%sper_class.tsv" % output_file ), sep = "\t", header = True)

# %%
# overall hier stats
(Hsummary) = overall_summary_stats(new_labels, classifications_test, graph, penalty=False)
print(Hsummary)
# Out:
# {'hR': 0.7047619047619048, 'hP': 0.7115384615384616, 'hF1': 0.7081339712918662, 'hAcc': 0.7142857142857139}

# %%
# classification per sample 
classification_table_renamed = pd.concat([raw_labels.rename(columns = {1:"labels"}), classification_table_test], axis=1).loc[new_labels.index]

classification_table_renamed.to_csv(( "%sper_sample.tsv" % output_file ), sep = "\t", header = True)

classification_table_renamed
# Out:
#             labels  classification  Americas  Europe  Africa   Asia  \
# ERR2278721  Poland         Hungary     0.070   0.677   0.009  0.244
# ERR2278723  Poland          Poland     0.037   0.707   0.009  0.247
# ERR2278728  Poland          Poland     0.036   0.701   0.020  0.243
# ERR2278729  Poland          Poland     0.034   0.688   0.009  0.269
# ERR2278733  Poland           Italy     0.027   0.854   0.031  0.088
# ERR2278739  Poland         Hungary     0.031   0.744   0.008  0.217
# ERR2278742  Poland          Poland     0.039   0.727   0.008  0.226
# ERR2278743  Poland          Poland     0.023   0.785   0.004  0.188
# ERR2278749  Poland  Eastern Europe     0.017   0.489   0.095  0.399
# ERR2278713  Poland          Greece     0.018   0.657   0.154  0.171
# ERR2278717  Poland        Portugal     0.055   0.653   0.049  0.243
# ERR2278720  Poland           Italy     0.070   0.682   0.038  0.210
# ERR2278726  Poland          Poland     0.091   0.646   0.012  0.251
# ERR2278727  Poland          Poland     0.069   0.654   0.012  0.265
# ERR2278735  Poland           Italy     0.056   0.688   0.026  0.230
# ERR2278716  Poland        Portugal     0.029   0.731   0.035  0.205
# ERR2278718  Poland          Poland     0.047   0.709   0.011  0.233
# ERR2278724  Poland          Poland     0.028   0.747   0.006  0.219
# ERR2278736  Poland        Portugal     0.050   0.705   0.042  0.203
# ERR2278738  Poland          Poland     0.031   0.735   0.006  0.228
# ERR2278731  Poland           Italy     0.049   0.737   0.030  0.184
# ERR2278734  Poland         Hungary     0.031   0.443   0.109  0.417
# ERR2278741  Poland         Hungary     0.072   0.683   0.012  0.233
# ERR2278745  Poland  Czech republic     0.065   0.713   0.061  0.161
# ERR2278714  Poland          Poland     0.063   0.709   0.012  0.216
# ERR2278715  Poland          Poland     0.019   0.761   0.013  0.207
# ERR2278719  Poland           Italy     0.048   0.665   0.025  0.262
# ERR2278722  Poland         Hungary     0.030   0.779   0.004  0.187
# ERR2278725  Poland          Poland     0.017   0.761   0.005  0.217
# ERR2278737  Poland           Italy     0.096   0.666   0.049  0.189
# ERR2278740  Poland          Poland     0.012   0.773   0.012  0.203
# ERR2278744  Poland          Poland     0.026   0.761   0.012  0.201
# ERR2278746  Poland          Greece     0.046   0.691   0.062  0.201
# ERR2278747  Poland          Greece     0.049   0.459   0.257  0.235
# ERR2278748  Poland      Cape verde     0.011   0.335   0.527  0.127
#
#             Latin America and the Caribbean  Northern America  Eastern Europe  \
# ERR2278721                              NaN               NaN           0.491
# ERR2278723                              NaN               NaN           0.535
# ERR2278728                              NaN               NaN           0.519
# ERR2278729                              NaN               NaN           0.563
# ERR2278733                              NaN               NaN           0.167
# ERR2278739                              NaN               NaN           0.551
# ERR2278742                              NaN               NaN           0.568
# ERR2278743                              NaN               NaN           0.590
# ERR2278749                              NaN               NaN           0.528
# ERR2278713                              NaN               NaN           0.380
# ERR2278717                              NaN               NaN           0.208
# ERR2278720                              NaN               NaN           0.431
# ERR2278726                              NaN               NaN           0.490
# ERR2278727                              NaN               NaN           0.499
# ERR2278735                              NaN               NaN           0.447
# ERR2278716                              NaN               NaN           0.107
# ERR2278718                              NaN               NaN           0.508
# ERR2278724                              NaN               NaN           0.499
# ERR2278736                              NaN               NaN           0.130
# ERR2278738                              NaN               NaN           0.536
# ERR2278731                              NaN               NaN           0.196
# ERR2278734                              NaN               NaN           0.559
# ERR2278741                              NaN               NaN           0.486
# ERR2278745                              NaN               NaN           0.532
# ERR2278714                              NaN               NaN           0.506
# ERR2278715                              NaN               NaN           0.603
# ERR2278719                              NaN               NaN           0.489
# ERR2278722                              NaN               NaN           0.614
# ERR2278725                              NaN               NaN           0.578
# ERR2278737                              NaN               NaN           0.454
# ERR2278740                              NaN               NaN           0.577
# ERR2278744                              NaN               NaN           0.555
# ERR2278746                              NaN               NaN           0.316
# ERR2278747                              NaN               NaN           0.480
# ERR2278748                              NaN               NaN             NaN
#
#             Western Europe  ...  Turkey  United Arab Emirates  India  \
# ERR2278721           0.039  ...     NaN                   NaN    NaN
# ERR2278723           0.029  ...     NaN                   NaN    NaN
# ERR2278728           0.035  ...     NaN                   NaN    NaN
# ERR2278729           0.019  ...     NaN                   NaN    NaN
# ERR2278733           0.009  ...     NaN                   NaN    NaN
# ERR2278739           0.022  ...     NaN                   NaN    NaN
# ERR2278742           0.038  ...     NaN                   NaN    NaN
# ERR2278743           0.004  ...     NaN                   NaN    NaN
# ERR2278749           0.021  ...     NaN                   NaN    NaN
# ERR2278713           0.005  ...     NaN                   NaN    NaN
# ERR2278717           0.031  ...     NaN                   NaN    NaN
# ERR2278720           0.043  ...     NaN                   NaN    NaN
# ERR2278726           0.034  ...     NaN                   NaN    NaN
# ERR2278727           0.035  ...     NaN                   NaN    NaN
# ERR2278735           0.045  ...     NaN                   NaN    NaN
# ERR2278716           0.017  ...     NaN                   NaN    NaN
# ERR2278718           0.020  ...     NaN                   NaN    NaN
# ERR2278724           0.016  ...     NaN                   NaN    NaN
# ERR2278736           0.037  ...     NaN                   NaN    NaN
# ERR2278738           0.026  ...     NaN                   NaN    NaN
# ERR2278731           0.012  ...     NaN                   NaN    NaN
# ERR2278734           0.022  ...     NaN                   NaN    NaN
# ERR2278741           0.038  ...     NaN                   NaN    NaN
# ERR2278745           0.018  ...     NaN                   NaN    NaN
# ERR2278714           0.027  ...     NaN                   NaN    NaN
# ERR2278715           0.006  ...     NaN                   NaN    NaN
# ERR2278719           0.022  ...     NaN                   NaN    NaN
# ERR2278722           0.008  ...     NaN                   NaN    NaN
# ERR2278725           0.015  ...     NaN                   NaN    NaN
# ERR2278737           0.035  ...     NaN                   NaN    NaN
# ERR2278740           0.006  ...     NaN                   NaN    NaN
# ERR2278744           0.023  ...     NaN                   NaN    NaN
# ERR2278746           0.030  ...     NaN                   NaN    NaN
# ERR2278747           0.005  ...     NaN                   NaN    NaN
# ERR2278748             NaN  ...     NaN                   NaN    NaN
#
#             Pakistan  Sri lanka  Indonesia  Malaysia  Singapore  Thailand  \
# ERR2278721       NaN        NaN        NaN       NaN        NaN       NaN
# ERR2278723       NaN        NaN        NaN       NaN        NaN       NaN
# ERR2278728       NaN        NaN        NaN       NaN        NaN       NaN
# ERR2278729       NaN        NaN        NaN       NaN        NaN       NaN
# ERR2278733       NaN        NaN        NaN       NaN        NaN       NaN
# ERR2278739       NaN        NaN        NaN       NaN        NaN       NaN
# ERR2278742       NaN        NaN        NaN       NaN        NaN       NaN
# ERR2278743       NaN        NaN        NaN       NaN        NaN       NaN
# ERR2278749       NaN        NaN        NaN       NaN        NaN       NaN
# ERR2278713       NaN        NaN        NaN       NaN        NaN       NaN
# ERR2278717       NaN        NaN        NaN       NaN        NaN       NaN
# ERR2278720       NaN        NaN        NaN       NaN        NaN       NaN
# ERR2278726       NaN        NaN        NaN       NaN        NaN       NaN
# ERR2278727       NaN        NaN        NaN       NaN        NaN       NaN
# ERR2278735       NaN        NaN        NaN       NaN        NaN       NaN
# ERR2278716       NaN        NaN        NaN       NaN        NaN       NaN
# ERR2278718       NaN        NaN        NaN       NaN        NaN       NaN
# ERR2278724       NaN        NaN        NaN       NaN        NaN       NaN
# ERR2278736       NaN        NaN        NaN       NaN        NaN       NaN
# ERR2278738       NaN        NaN        NaN       NaN        NaN       NaN
# ERR2278731       NaN        NaN        NaN       NaN        NaN       NaN
# ERR2278734       NaN        NaN        NaN       NaN        NaN       NaN
# ERR2278741       NaN        NaN        NaN       NaN        NaN       NaN
# ERR2278745       NaN        NaN        NaN       NaN        NaN       NaN
# ERR2278714       NaN        NaN        NaN       NaN        NaN       NaN
# ERR2278715       NaN        NaN        NaN       NaN        NaN       NaN
# ERR2278719       NaN        NaN        NaN       NaN        NaN       NaN
# ERR2278722       NaN        NaN        NaN       NaN        NaN       NaN
# ERR2278725       NaN        NaN        NaN       NaN        NaN       NaN
# ERR2278737       NaN        NaN        NaN       NaN        NaN       NaN
# ERR2278740       NaN        NaN        NaN       NaN        NaN       NaN
# ERR2278744       NaN        NaN        NaN       NaN        NaN       NaN
# ERR2278746       NaN        NaN        NaN       NaN        NaN       NaN
# ERR2278747       NaN        NaN        NaN       NaN        NaN       NaN
# ERR2278748       NaN        NaN        NaN       NaN        NaN       NaN
#
#             Vietnam
# ERR2278721      NaN
# ERR2278723      NaN
# ERR2278728      NaN
# ERR2278729      NaN
# ERR2278733      NaN
# ERR2278739      NaN
# ERR2278742      NaN
# ERR2278743      NaN
# ERR2278749      NaN
# ERR2278713      NaN
# ERR2278717      NaN
# ERR2278720      NaN
# ERR2278726      NaN
# ERR2278727      NaN
# ERR2278735      NaN
# ERR2278716      NaN
# ERR2278718      NaN
# ERR2278724      NaN
# ERR2278736      NaN
# ERR2278738      NaN
# ERR2278731      NaN
# ERR2278734      NaN
# ERR2278741      NaN
# ERR2278745      NaN
# ERR2278714      NaN
# ERR2278715      NaN
# ERR2278719      NaN
# ERR2278722      NaN
# ERR2278725      NaN
# ERR2278737      NaN
# ERR2278740      NaN
# ERR2278744      NaN
# ERR2278746      NaN
# ERR2278747      NaN
# ERR2278748      NaN
#
# [35 rows x 55 columns]

# %%
# save classified samples and summary data
hsum_file = "%shsummary.tab" % output_file

# Saving the reference of the standard output
original_stdout = sys.stdout    
 
with open(hsum_file, 'w') as f:
    
    # set stdout
    sys.stdout = f 
    
    # print data
    for i in Hsummary:
        print(i, "\t", Hsummary[i] )
    
    # Reset the standard output
    sys.stdout = original_stdout

# %%
# use standard assessment metrics per node (non-hierarchical)
(test_summary_per_node, test_summary_per_class, test_clf_tables) = per_node_summary_stats(graph, new_labels, input_converted, models, verbose = True)
test_summary_per_class.to_csv(( "%snonhier_per_class.tsv" % output_file ), sep = "\t", header = True)
# Out:
# classes in model:['Africa' 'Americas' 'Asia' 'Europe']
# /home/sbayliss/miniconda3/envs/PHE_ML_CLIMB_version/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sbayliss/miniconda3/envs/PHE_ML_CLIMB_version/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sbayliss/miniconda3/envs/PHE_ML_CLIMB_version/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sbayliss/miniconda3/envs/PHE_ML_CLIMB_version/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1854: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# classes in model:['Northern Africa' 'Sub-Saharan Africa']
# classes in model:['Latin America and the Caribbean' 'Northern America']
# classes in model:['Eastern Asia' 'South-eastern Asia' 'Southern Asia' 'Western Asia']
# classes in model:['Eastern Europe' 'Southern Europe' 'Western Europe']
# /home/sbayliss/miniconda3/envs/PHE_ML_CLIMB_version/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sbayliss/miniconda3/envs/PHE_ML_CLIMB_version/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sbayliss/miniconda3/envs/PHE_ML_CLIMB_version/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sbayliss/miniconda3/envs/PHE_ML_CLIMB_version/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1854: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# classes in model:['Bulgaria' 'Czech republic' 'Hungary' 'Poland' 'Russian federation']
# classes in model:['Barbados' 'Cuba' 'Dominica' 'Dominican republic' 'Jamaica' 'Mexico']
# classes in model:['Egypt' 'Morocco' 'Tunisia']
# classes in model:['Indonesia' 'Malaysia' 'Singapore' 'Thailand' 'Vietnam']
# classes in model:['India' 'Pakistan' 'Sri lanka']
# classes in model:['Greece' 'Italy' 'Malta' 'Portugal' 'Spain']
# classes in model:['Cape verde' 'Kenya' 'South africa' 'Tanzania']
# classes in model:['Cyprus' 'Saudi arabia' 'Turkey' 'United Arab Emirates']
# /home/sbayliss/miniconda3/envs/PHE_ML_CLIMB_version/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sbayliss/miniconda3/envs/PHE_ML_CLIMB_version/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sbayliss/miniconda3/envs/PHE_ML_CLIMB_version/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sbayliss/miniconda3/envs/PHE_ML_CLIMB_version/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1854: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
