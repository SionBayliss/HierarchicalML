# %% [markdown]
# # classify new data using pre-run model

# %%
# dependencies 
import networkx as nx
import numpy as np
import pandas as pd

import copy 
import sys
import gzip
import pickle
import time

from sklearn.model_selection import train_test_split, RandomizedSearchCV, StratifiedKFold, cross_validate
from sklearn.metrics import accuracy_score, balanced_accuracy_score, confusion_matrix, classification_report

from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import SelectFromModel

# import hierarchical classification package
sys.path.append( '../../HC_package/' )
from HierarchicalClassification import *

# %%
# set variables 
data_file = "patterns.tab"
class_file = "sample.location" 
output_file = "output_"
include_file = "sample_list.txt"

n_jobs = -1
seed = 34

# %%
# classificaton mode and thresholds
mode = 'max' # maximum class proedicted probability
threshold = 'adaptive' # minimum threshold value is 1/number of classes in model - this can also be a set value e.g. 0.5

# %% [markdown]
# ## load dataset and expected classes

# %%
# features
raw_features  = pd.read_csv(data_file, sep = "\t", index_col = "pattern_id")

# %%
# labels 
raw_labels = pd.read_csv(class_file, sep = "\t", header = None, index_col = 0)

# samples to include - just an index
include = pd.read_csv(include_file, sep = "\t", header = None, index_col = 0)

# %%
# find intersection between sample list and those included in features
inc = include.index.values
in_feat = raw_features.columns

intersect = []
for i in include.index.values:
    if i in in_feat:
        intersect.append(i)
        
print("original samples to include:", len(inc))
print("samples present in data:", len(intersect))
# Out:
# original samples to include: 25
# samples present in data: 25

# %%
# filter feature/labels on include
new_features = raw_features.loc[:, intersect]

# %%
# order labels on colnames of features
lab_ind = pd.DataFrame(index=new_features.columns)
new_labels = lab_ind.join(raw_labels)[1]

print(new_features.shape)
print(new_labels.shape)
# Out:
# (94860, 25)
# (25,)

# %% [markdown]
# ## load required prefiltering methods

# %%
# random forest to select features based on GINI
class RF_FS:
     
    def __init__(self, n=100, n_estimators=1000, random_state=0, n_jobs=-1):
        self.name = 'RF_FS'
        self.scores = None
        self.n = n
        self.n_estimators = n_estimators
        self.n_jobs = n_jobs
        self.random_state = random_state
        
    def classifier(self):
        return(self.name)
    
    def fit(self, feat, lab):
        
        # fit model
        fs = RandomForestClassifier(n_estimators=self.n_estimators, random_state=self.random_state, n_jobs=self.n_jobs)
        fs.fit(feat, lab)
      
        # make score / feature id dataframe 
        self.scores = pd.DataFrame(index = feat.columns.values)
        self.scores['scores'] = copy.copy(fs.feature_importances_)
        
        # sort scores
        self.scores.sort_values(by=['scores'], ascending=False, inplace=True)

        return(self)
    
    def transform(self, feat):
        
        # select top scores /transform input data
        ind = self.scores['scores'][0:self.n].index.values # get indices of top hits
        out_feat  = feat.loc[:,ind] # select input cols on indices
      
        # return no_selected top features
        return(copy.copy(out_feat))
    
    def fit_transform(self, feat, lab):
        self.fit(feat, lab)
        out_feat = self.transform(feat)
        return(out_feat)
    
    def plot(self):

        # plot sorted scores
        x=np.r_[0:len(self.scores['scores'])]
        plt.plot(x, self.scores['scores'])
        plt.vlines(x = self.n, ymin = 0, ymax = max(self.scores['scores']), 
               colors = 'red')

# %%
# load model and associated data 
pkl = "/home/sbayliss/Desktop/projects/PHE_Salmonella/notebooks/github/HierarchicalML/optimised_model/optimised_model_data.pkl"
with gzip.open(pkl, 'rb') as f:
    
    models = pickle.load(f)
    train_features = pickle.load(f)
    graph = pickle.load(f)

# %%
input_converted = copy.copy(new_features.loc[train_features].T)
print(input_converted.shape)
input_converted
# Out:
# (25, 94860)
# pattern_id   1       2       3       4       5       6       7       8       \
# SRR12223838       1       1       1       1       1       1       1       1
# SRR12223839       1       1       1       1       1       1       1       1
# SRR12223842       1       1       1       1       1       1       1       1
# SRR12223843       1       1       1       1       1       1       1       1
# SRR12223846       1       1       1       1       1       1       1       1
# SRR12223852       1       1       1       1       1       1       1       1
# SRR12223853       1       1       1       1       1       1       1       1
# SRR12223831       1       1       1       1       1       1       1       1
# SRR12223834       1       1       1       1       1       1       1       1
# SRR12223836       1       1       1       1       1       1       1       1
# SRR12223837       1       1       1       1       1       1       1       1
# SRR12223840       1       1       1       1       1       1       1       1
# SRR12223832       1       1       1       1       1       1       1       1
# SRR12223841       1       1       1       1       1       1       1       1
# SRR12223849       1       1       1       1       1       1       1       1
# SRR12223851       1       1       1       1       1       1       1       1
# SRR12223854       1       1       1       1       1       1       1       1
# SRR12223844       1       1       1       1       1       1       1       1
# SRR12223845       1       1       1       1       1       1       1       1
# SRR12223847       1       1       1       1       1       1       1       1
# SRR12223850       1       1       1       1       1       1       1       1
# SRR12223855       1       1       1       1       1       1       1       1
# SRR12223833       1       1       1       1       1       1       1       1
# SRR12223835       1       1       1       1       1       1       1       1
# SRR12223848       1       1       1       1       1       1       1       1
#
# pattern_id   12      13      ...  110471  110472  110474  110476  110477  \
# SRR12223838       0       1  ...       0       0       1       0       0
# SRR12223839       0       1  ...       0       0       1       0       0
# SRR12223842       0       1  ...       0       0       1       0       0
# SRR12223843       0       1  ...       0       0       1       0       0
# SRR12223846       0       1  ...       0       0       1       0       0
# SRR12223852       0       1  ...       0       0       1       0       0
# SRR12223853       0       1  ...       0       0       1       0       0
# SRR12223831       0       1  ...       0       0       1       0       0
# SRR12223834       0       1  ...       0       0       1       0       0
# SRR12223836       0       1  ...       0       0       1       0       0
# SRR12223837       0       1  ...       0       0       1       0       0
# SRR12223840       0       1  ...       0       0       1       0       0
# SRR12223832       0       1  ...       0       0       1       0       0
# SRR12223841       0       1  ...       0       0       1       0       0
# SRR12223849       0       1  ...       0       0       1       0       0
# SRR12223851       0       1  ...       0       0       1       0       0
# SRR12223854       0       1  ...       0       0       1       0       0
# SRR12223844       0       1  ...       0       0       1       0       0
# SRR12223845       0       1  ...       0       0       1       0       0
# SRR12223847       0       1  ...       0       0       1       0       0
# SRR12223850       0       1  ...       0       0       1       0       0
# SRR12223855       0       1  ...       0       0       1       0       0
# SRR12223833       0       1  ...       0       0       1       0       0
# SRR12223835       0       1  ...       0       0       1       0       0
# SRR12223848       0       1  ...       0       0       1       0       0
#
# pattern_id   110479  110480  110481  110482  110483
# SRR12223838       0       0       0       0       0
# SRR12223839       0       0       0       0       0
# SRR12223842       0       0       0       0       0
# SRR12223843       0       0       0       0       0
# SRR12223846       0       0       0       0       0
# SRR12223852       0       0       0       0       0
# SRR12223853       0       0       0       0       0
# SRR12223831       0       0       0       0       0
# SRR12223834       0       0       0       0       0
# SRR12223836       0       0       0       0       0
# SRR12223837       0       0       0       0       0
# SRR12223840       0       0       0       0       0
# SRR12223832       0       0       0       0       0
# SRR12223841       0       0       0       0       0
# SRR12223849       0       0       0       0       0
# SRR12223851       0       0       0       0       0
# SRR12223854       0       0       0       0       0
# SRR12223844       0       0       0       0       0
# SRR12223845       0       0       0       0       0
# SRR12223847       0       0       0       0       0
# SRR12223850       0       0       0       0       0
# SRR12223855       0       0       0       0       0
# SRR12223833       0       0       0       0       0
# SRR12223835       0       0       0       0       0
# SRR12223848       0       0       0       0       0
#
# [25 rows x 94860 columns]

# %% [markdown]
# ## classify samples

# %%
# classify samples
timeb4 = time.time()

# classify test sample
(classification_table_test, classifications_test) = classify_samples_in_hierarchy(graph, input_converted, 
                                                                           models,
                                                                           mode = mode, 
                                                                           threshold = threshold)


timeafter = time.time()
total_seconds = timeafter-timeb4
print("classification took ", total_seconds, " seconds")
# Out:
# classification took  0.44966888427734375  seconds

# %%
# generate per class statistics
(summary_test, summary_table_test) = summary_statistics_per_class(graph, new_labels, classifications_test,
                                                                         penalty=False, macro_inc_all = False)
#print( summary_test, summary_table_test) 
print(summary_test['macro'])
print(summary_test['micro'])
# Out:
# {'hR': 1.0, 'hP': 1.0, 'F1': 1.0}
# {'hR': 1.0, 'hP': 1.0, 'F1': 1.0}

# %%
# convert class dist into table 

# create df
col_names = ["hP", "hR", "hF1", "n", "nP", "nT", "root_dist"]
class_table =  pd.DataFrame(
    columns = col_names,
    index = summary_test['per_class'])

# fill table
for i in summary_test['per_class']:
    for j in col_names:
        class_table.loc[i, j] = summary_test['per_class'][i][j]
    
# sort on class names and root_dist 
class_table.sort_index(inplace=True)
class_table.sort_values(by=['root_dist'], inplace=True)

# %%
# save per class hierachical summary values 
class_table.to_csv(( "%sper_class.tsv" % output_file ), sep = "\t", header = True)

# %%
# overall hier stats
(Hsummary) = overall_summary_stats(new_labels, classifications_test, graph, penalty=False)
print(Hsummary)
# Out:
# {'hR': 1.0, 'hP': 1.0, 'hF1': 1.0, 'hAcc': 1.0}

# %%
# classification per sample 
classification_table_renamed = pd.concat([raw_labels.rename(columns = {1:"labels"}), classification_table_test], axis=1).loc[new_labels.index]

classification_table_renamed.to_csv(( "%sper_sample.tsv" % output_file ), sep = "\t", header = True)

classification_table_renamed
# Out:
#                    labels classification  Americas  Europe  Africa  Asia  \
# SRR12223838  South africa   South africa       0.0     0.0     1.0   0.0
# SRR12223839  South africa   South africa       0.0     0.0     1.0   0.0
# SRR12223842  South africa   South africa       0.0     0.0     1.0   0.0
# SRR12223843  South africa   South africa       0.0     0.0     1.0   0.0
# SRR12223846  South africa   South africa       0.0     0.0     1.0   0.0
# SRR12223852  South africa   South africa       0.0     0.0     1.0   0.0
# SRR12223853  South africa   South africa       0.0     0.0     1.0   0.0
# SRR12223831  South africa   South africa       0.0     0.0     1.0   0.0
# SRR12223834  South africa   South africa       0.0     0.0     1.0   0.0
# SRR12223836  South africa   South africa       0.0     0.0     1.0   0.0
# SRR12223837  South africa   South africa       0.0     0.0     1.0   0.0
# SRR12223840  South africa   South africa       0.0     0.0     1.0   0.0
# SRR12223832  South africa   South africa       0.0     0.0     1.0   0.0
# SRR12223841  South africa   South africa       0.0     0.0     1.0   0.0
# SRR12223849  South africa   South africa       0.0     0.0     1.0   0.0
# SRR12223851  South africa   South africa       0.0     0.0     1.0   0.0
# SRR12223854  South africa   South africa       0.0     0.0     1.0   0.0
# SRR12223844  South africa   South africa       0.0     0.0     1.0   0.0
# SRR12223845  South africa   South africa       0.0     0.0     1.0   0.0
# SRR12223847  South africa   South africa       0.0     0.0     1.0   0.0
# SRR12223850  South africa   South africa       0.0     0.0     1.0   0.0
# SRR12223855  South africa   South africa       0.0     0.0     1.0   0.0
# SRR12223833  South africa   South africa       0.0     0.0     1.0   0.0
# SRR12223835  South africa   South africa       0.0     0.0     1.0   0.0
# SRR12223848  South africa   South africa       0.0     0.0     1.0   0.0
#
#              Latin America and the Caribbean  Northern America  \
# SRR12223838                              NaN               NaN
# SRR12223839                              NaN               NaN
# SRR12223842                              NaN               NaN
# SRR12223843                              NaN               NaN
# SRR12223846                              NaN               NaN
# SRR12223852                              NaN               NaN
# SRR12223853                              NaN               NaN
# SRR12223831                              NaN               NaN
# SRR12223834                              NaN               NaN
# SRR12223836                              NaN               NaN
# SRR12223837                              NaN               NaN
# SRR12223840                              NaN               NaN
# SRR12223832                              NaN               NaN
# SRR12223841                              NaN               NaN
# SRR12223849                              NaN               NaN
# SRR12223851                              NaN               NaN
# SRR12223854                              NaN               NaN
# SRR12223844                              NaN               NaN
# SRR12223845                              NaN               NaN
# SRR12223847                              NaN               NaN
# SRR12223850                              NaN               NaN
# SRR12223855                              NaN               NaN
# SRR12223833                              NaN               NaN
# SRR12223835                              NaN               NaN
# SRR12223848                              NaN               NaN
#
#              Eastern Europe  Western Europe  ...  Turkey  \
# SRR12223838             NaN             NaN  ...     NaN
# SRR12223839             NaN             NaN  ...     NaN
# SRR12223842             NaN             NaN  ...     NaN
# SRR12223843             NaN             NaN  ...     NaN
# SRR12223846             NaN             NaN  ...     NaN
# SRR12223852             NaN             NaN  ...     NaN
# SRR12223853             NaN             NaN  ...     NaN
# SRR12223831             NaN             NaN  ...     NaN
# SRR12223834             NaN             NaN  ...     NaN
# SRR12223836             NaN             NaN  ...     NaN
# SRR12223837             NaN             NaN  ...     NaN
# SRR12223840             NaN             NaN  ...     NaN
# SRR12223832             NaN             NaN  ...     NaN
# SRR12223841             NaN             NaN  ...     NaN
# SRR12223849             NaN             NaN  ...     NaN
# SRR12223851             NaN             NaN  ...     NaN
# SRR12223854             NaN             NaN  ...     NaN
# SRR12223844             NaN             NaN  ...     NaN
# SRR12223845             NaN             NaN  ...     NaN
# SRR12223847             NaN             NaN  ...     NaN
# SRR12223850             NaN             NaN  ...     NaN
# SRR12223855             NaN             NaN  ...     NaN
# SRR12223833             NaN             NaN  ...     NaN
# SRR12223835             NaN             NaN  ...     NaN
# SRR12223848             NaN             NaN  ...     NaN
#
#              United Arab Emirates  India  Pakistan  Sri lanka  Indonesia  \
# SRR12223838                   NaN    NaN       NaN        NaN        NaN
# SRR12223839                   NaN    NaN       NaN        NaN        NaN
# SRR12223842                   NaN    NaN       NaN        NaN        NaN
# SRR12223843                   NaN    NaN       NaN        NaN        NaN
# SRR12223846                   NaN    NaN       NaN        NaN        NaN
# SRR12223852                   NaN    NaN       NaN        NaN        NaN
# SRR12223853                   NaN    NaN       NaN        NaN        NaN
# SRR12223831                   NaN    NaN       NaN        NaN        NaN
# SRR12223834                   NaN    NaN       NaN        NaN        NaN
# SRR12223836                   NaN    NaN       NaN        NaN        NaN
# SRR12223837                   NaN    NaN       NaN        NaN        NaN
# SRR12223840                   NaN    NaN       NaN        NaN        NaN
# SRR12223832                   NaN    NaN       NaN        NaN        NaN
# SRR12223841                   NaN    NaN       NaN        NaN        NaN
# SRR12223849                   NaN    NaN       NaN        NaN        NaN
# SRR12223851                   NaN    NaN       NaN        NaN        NaN
# SRR12223854                   NaN    NaN       NaN        NaN        NaN
# SRR12223844                   NaN    NaN       NaN        NaN        NaN
# SRR12223845                   NaN    NaN       NaN        NaN        NaN
# SRR12223847                   NaN    NaN       NaN        NaN        NaN
# SRR12223850                   NaN    NaN       NaN        NaN        NaN
# SRR12223855                   NaN    NaN       NaN        NaN        NaN
# SRR12223833                   NaN    NaN       NaN        NaN        NaN
# SRR12223835                   NaN    NaN       NaN        NaN        NaN
# SRR12223848                   NaN    NaN       NaN        NaN        NaN
#
#              Malaysia  Singapore  Thailand  Vietnam
# SRR12223838       NaN        NaN       NaN      NaN
# SRR12223839       NaN        NaN       NaN      NaN
# SRR12223842       NaN        NaN       NaN      NaN
# SRR12223843       NaN        NaN       NaN      NaN
# SRR12223846       NaN        NaN       NaN      NaN
# SRR12223852       NaN        NaN       NaN      NaN
# SRR12223853       NaN        NaN       NaN      NaN
# SRR12223831       NaN        NaN       NaN      NaN
# SRR12223834       NaN        NaN       NaN      NaN
# SRR12223836       NaN        NaN       NaN      NaN
# SRR12223837       NaN        NaN       NaN      NaN
# SRR12223840       NaN        NaN       NaN      NaN
# SRR12223832       NaN        NaN       NaN      NaN
# SRR12223841       NaN        NaN       NaN      NaN
# SRR12223849       NaN        NaN       NaN      NaN
# SRR12223851       NaN        NaN       NaN      NaN
# SRR12223854       NaN        NaN       NaN      NaN
# SRR12223844       NaN        NaN       NaN      NaN
# SRR12223845       NaN        NaN       NaN      NaN
# SRR12223847       NaN        NaN       NaN      NaN
# SRR12223850       NaN        NaN       NaN      NaN
# SRR12223855       NaN        NaN       NaN      NaN
# SRR12223833       NaN        NaN       NaN      NaN
# SRR12223835       NaN        NaN       NaN      NaN
# SRR12223848       NaN        NaN       NaN      NaN
#
# [25 rows x 55 columns]

# %%
# save classified samples and summary data
hsum_file = "%shsummary.tab" % output_file

# Saving the reference of the standard output
original_stdout = sys.stdout    
 
with open(hsum_file, 'w') as f:
    
    # set stdout
    sys.stdout = f 
    
    # print data
    for i in Hsummary:
        print(i, "\t", Hsummary[i] )
    
    # Reset the standard output
    sys.stdout = original_stdout

# %%
# use standard assessment metrics per node (non-hierarchical)
(test_summary_per_node, test_summary_per_class, test_clf_tables) = per_node_summary_stats(graph, new_labels, input_converted, models, verbose = True)
test_summary_per_class.to_csv(( "%snonhier_per_class.tsv" % output_file ), sep = "\t", header = True)
# Out:
# classes in model:['Africa' 'Americas' 'Asia' 'Europe']
# classes in model:['Northern Africa' 'Sub-Saharan Africa']
# /home/sbayliss/miniconda3/envs/PHE_ML_CLIMB_version/lib/python3.9/site-packages/sklearn/metrics/_classification.py:641: RuntimeWarning: invalid value encountered in true_divide
#   k = np.sum(w_mat * confusion) / np.sum(w_mat * expected)
# /home/sbayliss/miniconda3/envs/PHE_ML_CLIMB_version/lib/python3.9/site-packages/sklearn/metrics/_classification.py:641: RuntimeWarning: invalid value encountered in true_divide
#   k = np.sum(w_mat * confusion) / np.sum(w_mat * expected)
# classes in model:['Latin America and the Caribbean' 'Northern America']
# classes in model:['Eastern Asia' 'South-eastern Asia' 'Southern Asia' 'Western Asia']
# classes in model:['Eastern Europe' 'Southern Europe' 'Western Europe']
# classes in model:['Bulgaria' 'Czech republic' 'Hungary' 'Poland' 'Russian federation']
# classes in model:['Barbados' 'Cuba' 'Dominica' 'Dominican republic' 'Jamaica' 'Mexico']
# classes in model:['Egypt' 'Morocco' 'Tunisia']
# classes in model:['Indonesia' 'Malaysia' 'Singapore' 'Thailand' 'Vietnam']
# classes in model:['India' 'Pakistan' 'Sri lanka']
# classes in model:['Greece' 'Italy' 'Malta' 'Portugal' 'Spain']
# classes in model:['Cape verde' 'Kenya' 'South africa' 'Tanzania']
# classes in model:['Cyprus' 'Saudi arabia' 'Turkey' 'United Arab Emirates']
# /home/sbayliss/miniconda3/envs/PHE_ML_CLIMB_version/lib/python3.9/site-packages/sklearn/metrics/_classification.py:641: RuntimeWarning: invalid value encountered in true_divide
#   k = np.sum(w_mat * confusion) / np.sum(w_mat * expected)
